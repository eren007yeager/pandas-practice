# %% [markdown]
# #read csv file

# %%
import pandas as pd
csv_1= pd.read_csv("C:\\Users\\chand\\Downloads\\Project-Management-Sample-Data.csv")
csv_1
# Out:
#           Excel Sample Data               Unnamed: 1   Unnamed: 2  Unnamed: 3  \
# 0                       NaN                      NaN          NaN         NaN
# 1   Project Management Data                      NaN          NaN         NaN
# 2                       NaN                      NaN          NaN         NaN
# 3              Project Name                Task Name  Assigned to  Start Date
# 4                 Marketing          Market Research        Alice  01-01-2024
# 5                 Marketing         Content Creation          Bob  14-01-2024
# 6                 Marketing    Social Media Planning      Charlie  28-01-2024
# 7                 Marketing        Campaign Analysis        Daisy  18-02-2024
# 8               Product Dev    Prototype Development        Ethan  02-01-2024
# 9               Product Dev        Quality Assurance        Fiona  20-01-2024
# 10              Product Dev    User Interface Design      Gabriel  04-02-2024
# ...

# %%
import pandas as pd
csv_2= pd.read_csv("C:\\Users\\chand\\Downloads\\Project-Management-Sample-Data.csv",nrows=5)
print(type(csv_2))
print(csv_2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#          Excel Sample Data       Unnamed: 1   Unnamed: 2  Unnamed: 3  \
# 0                      NaN              NaN          NaN         NaN
# 1  Project Management Data              NaN          NaN         NaN
# 2                      NaN              NaN          NaN         NaN
# 3             Project Name        Task Name  Assigned to  Start Date
# 4                Marketing  Market Research        Alice  01-01-2024
#
#       Unnamed: 4  Unnamed: 5 Unnamed: 6
# 0            NaN         NaN        NaN
# 1            NaN         NaN        NaN
# 2            NaN         NaN        NaN
# 3  Days Required    End Date   Progress
# 4             13  14-01-2024        78%

# %%
#for getting an perticular collumn
csv_3 = pd.read_csv("C:\\Users\\chand\\Downloads\\Project-Management-Sample-Data.csv",usecols=[0,3],header=3)
print(csv_3)
# Out:
#       Unnamed: 0  Unnamed: 3
# 0   Project Name  Start Date
# 1      Marketing  01-01-2024
# 2      Marketing  14-01-2024
# 3      Marketing  28-01-2024
# 4      Marketing  18-02-2024
# 5    Product Dev  02-01-2024
# 6    Product Dev  20-01-2024
# 7    Product Dev  04-02-2024
# 8   Customer Svc  01-02-2024
# 9   Customer Svc  24-02-2024
# 10  Customer Svc  21-03-2024
# 11     Financial  02-02-2024
# 12     Financial  13-02-2024
# 13     Financial  19-03-2024
# 14      Research  02-01-2024
# 15      Research  26-01-2024
# 16      Research  28-02-2024
# 17   Development  02-01-2024
# 18   Development  08-02-2024
# 19   Development  14-03-2024
# 20    Production  03-01-2024
# 21    Production  17-02-2024
# 22    Production  14-03-2024
# 23         Sales  03-01-2024
# 24         Sales  06-01-2024
# 25         Sales  03-02-2024
# 26       Support  01-01-2024
# 27       Support  27-01-2024
# 28       Support  02-03-2024
# 29    Operations  03-01-2024
# 30    Operations  03-02-2024
# ...

# %%
csv_3 = pd.read_csv("C:\\Users\\chand\\Downloads\\Project-Management-Sample-Data.csv", skiprows=[0,4], index_col=None,header=3)
print(csv_3)
# Out:
#        Marketing          Market Research     Alice  01-01-2024  13  \
# 0      Marketing         Content Creation       Bob  14-01-2024  14
# 1      Marketing    Social Media Planning   Charlie  28-01-2024  22
# 2      Marketing        Campaign Analysis     Daisy  18-02-2024  25
# 3    Product Dev    Prototype Development     Ethan  02-01-2024  18
# 4    Product Dev        Quality Assurance     Fiona  20-01-2024  10
# 5    Product Dev    User Interface Design   Gabriel  04-02-2024  25
# 6   Customer Svc      Service Improvement    Hannah  01-02-2024  22
# 7   Customer Svc        Ticket Resolution       Ian  24-02-2024  25
# 8   Customer Svc        Customer Feedback     Julia  21-03-2024  30
# 9      Financial          Budget Analysis     Kevin  02-02-2024  22
# 10     Financial      Financial Reporting      Mark  13-02-2024  21
# 11     Financial      Investment Planning      Mark  19-03-2024  25
# 12      Research   Market Trends Analysis    Nathan  02-01-2024  23
# ...

# %%
csv_3 = pd.read_csv("C:\\Users\\chand\\Downloads\\Project-Management-Sample-Data.csv",names=["yogi1","yogi2","yogi3","yogi4","yogi5","yogi6","yogi7"])
print(csv_3)
# Out:
#                       yogi1                    yogi2        yogi3       yogi4  \
# 0         Excel Sample Data                      NaN          NaN         NaN
# 1                       NaN                      NaN          NaN         NaN
# 2   Project Management Data                      NaN          NaN         NaN
# 3                       NaN                      NaN          NaN         NaN
# 4              Project Name                Task Name  Assigned to  Start Date
# 5                 Marketing          Market Research        Alice  01-01-2024
# 6                 Marketing         Content Creation          Bob  14-01-2024
# 7                 Marketing    Social Media Planning      Charlie  28-01-2024
# 8                 Marketing        Campaign Analysis        Daisy  18-02-2024
# 9               Product Dev    Prototype Development        Ethan  02-01-2024
# 10              Product Dev        Quality Assurance        Fiona  20-01-2024
# ...

# %%
csv_3 = pd.read_csv("C:\\Users\\chand\\Downloads\\Project-Management-Sample-Data.csv", 
                        header=None, 
                        names=[f"coco_{i}" for i in range(10)],dtype={"coco_5":"object"})
print(csv_3)
# Out:
#                      coco_0                   coco_1       coco_2      coco_3  \
# 0         Excel Sample Data                      NaN          NaN         NaN
# 1                       NaN                      NaN          NaN         NaN
# 2   Project Management Data                      NaN          NaN         NaN
# 3                       NaN                      NaN          NaN         NaN
# 4              Project Name                Task Name  Assigned to  Start Date
# 5                 Marketing          Market Research        Alice  01-01-2024
# 6                 Marketing         Content Creation          Bob  14-01-2024
# 7                 Marketing    Social Media Planning      Charlie  28-01-2024
# 8                 Marketing        Campaign Analysis        Daisy  18-02-2024
# 9               Product Dev    Prototype Development        Ethan  02-01-2024
# 10              Product Dev        Quality Assurance        Fiona  20-01-2024
# ...

# %%
import pandas as pd

csv_3 = pd.read_csv("C:\\Users\\chand\\Downloads\\Project-Management-Sample-Data.csv", 
nrows=4, 
usecols=[0, 2, 4], 
skiprows=5, 
index_col=0, 
header=0, 
names=[f"coco_{i}" for i in range(7)], 
dtype={"Column2": "float"})

print(csv_3)
# Out:
#               coco_2  coco_4
# coco_0
# Marketing        Bob      14
# Marketing    Charlie      22
# Marketing      Daisy      25
# Product Dev    Ethan      18
