# %%
import pandas as pd
def convert_ProductName_cell(cell):
    if cell=="NaN":
        return "yogi"
    return cell    
df = pd.read_excel("C:\\Users\\chand\\Downloads\\Inventory-Records-Sample-Data.xlsx",converters={"ProductName":convert_ProductName_cell})
df
# Out:
#     Unnamed: 0              Unnamed: 1                   Unnamed: 2  \
# 0          NaN       Excel Sample Data                          NaN
# 1          NaN                     NaN                          NaN
# 2          NaN  Inventory Records Data                          NaN
# 3          NaN                     NaN                          NaN
# 4          NaN              Product ID                 Product Name
# 5          NaN                    P101                       Laptop
# 6          NaN                    P102                      Monitor
# 7          NaN                    P103                     Keyboard
# 8          NaN                    P104                   Headphones
# 9          NaN                    P105                   Smartphone
# 10         NaN                    P106                       Tablet
# 11         NaN                    P107                       Router
# 12         NaN                    P108          External Hard Drive
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0              Unnamed: 1    Unnamed: 2       Unnamed: 3  \
# 0         NaN       Excel Sample Data           NaN              NaN
# 1         NaN                     NaN           NaN              NaN
# 2         NaN  Inventory Records Data           NaN              NaN
# 3         NaN                     NaN           NaN              NaN
# 4         NaN              Product ID  Product Name  Opening \nStock
#
#             Unnamed: 4              Unnamed: 5       Unnamed: 6  \
# 0                  NaN                     NaN              NaN
# 1                  NaN                     NaN              NaN
# 2                  NaN                     NaN              NaN
# 3                  NaN                     NaN              NaN
# 4  Purchase/\nStock in  Number of \nUnits Sold  Hand-In-\nStock
#
#                     Unnamed: 7               Unnamed: 8
# 0                          NaN                      NaN
# ...

# %%
df.tail(5)
# Out:
#     Unnamed: 0 Unnamed: 1        Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 46         NaN       P142     USB-C Adapter         20         10          4
# 47         NaN       P143     Laptop Sleeve         30         12          5
# 48         NaN       P144  Wireless Charger         40         18          7
# 49         NaN       P145       USB-C Cable         50         20          9
# 50         NaN       P146       Gaming Desk         25         10          3
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 46         24         15        360
# 47         37         20        740
# 48         51         30       1530
# 49         61          8        488
# 50         28        150       4200

# %%
import pandas as pd
df = pd.read_excel("C:\\Users\\chand\\Downloads\\Inventory-Records-Sample-Data.xlsx")
print(df.dtypes)
# Out:
# Unnamed: 0    float64
# Unnamed: 1     object
# Unnamed: 2     object
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6     object
# Unnamed: 7     object
# Unnamed: 8     object
# dtype: object

# %%
df.describe()
# Out:
#        Unnamed: 0
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
import pandas as pd
data={"name":["yogi","jogi","mogi","dogi"],"age":[20,10,50,31],"salary":[2300,6500,3210,5644]}
df=pd.DataFrame(data)
file_path="exam.xlsx"
df.to_excel(file_path,sheet_name="employee",startrow=1,startcol=2,index=False)
df
# Out:
#    name  age  salary
# 0  yogi   20    2300
# 1  jogi   10    6500
# 2  mogi   50    3210
# 3  dogi   31    5644

# %%
import pandas as pd
df1=df_employee=pd.DataFrame({"name":["yogi","jogi","mogi","dogi"],
                          "age":[20,10,50,31],
                          "salary":[2300,6500,3210,5644]})

df1
# Out:
#    name  age  salary
# 0  yogi   20    2300
# 1  jogi   10    6500
# 2  mogi   50    3210
# 3  dogi   31    5644

# %%
df2=df_stocks=pd.DataFrame({"name":["jio","tata","audi"],
                          "price":[20000,10000,50000],
                          "groth":["25%","52%","36%"]})
df2
# Out:
#    name  price groth
# 0   jio  20000   25%
# 1  tata  10000   52%
# 2  audi  50000   36%

# %%
with pd.ExcelWriter("employee_stocks.xlsx") as writer:
    df_employee.to_excel(writer,sheet_name="employee")
    df_stocks.to_excel(writer,sheet_name="stocks")

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\chand\OneDrive\Documents\WEATHER_FILE.csv", parse_dates=["day"])
df.set_index("day",inplace=True)
df
# Out:
#             temp  windspeed  event
# day
# 2017-03-05  32.2        6.0   RAIN
# 2013-02-06   NaN        6.5  SUNNY
# 2018-06-12  70.0        3.1    NaN

# %%
new_df=df.fillna("invalid")
new_df
# Out:
#                temp  windspeed    event
# day
# 2017-03-05     32.2        6.0     RAIN
# 2013-02-06  invalid        6.5    SUNNY
# 2018-06-12     70.0        3.1  invalid

# %%
new_df=df.fillna({"temp":0,"windspeed":0,
               "event":"no_event"})
new_df
# Out:
#             temp  windspeed     event
# day
# 2017-03-05  32.2        6.0      RAIN
# 2013-02-06   0.0        6.5     SUNNY
# 2018-06-12  70.0        3.1  no_event

# %%
new_df.bfill(axis="columns",limit=2)
new_df
# Out:
#             temp  windspeed     event
# day
# 2017-03-05  32.2        6.0      RAIN
# 2013-02-06   0.0        6.5     SUNNY
# 2018-06-12  70.0        3.1  no_event

# %%
new_df = df.interpolate()
new_df
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_14580\812076388.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate()
#             temp  windspeed  event
# day
# 2017-03-05  32.2        6.0   RAIN
# 2013-02-06  51.1        6.5  SUNNY
# 2018-06-12  70.0        3.1    NaN

# %%
new_df=df.dropna()
new_df
# Out:
#             temp  windspeed event
# day
# 2017-03-05  32.2        6.0  RAIN

# %%
new_df=df.dropna(thresh=1)
new_df
# Out:
#             temp  windspeed  event
# day
# 2017-03-05  32.2        6.0   RAIN
# 2013-02-06   NaN        6.5  SUNNY
# 2018-06-12  70.0        3.1    NaN

# %%
dt = pd.date_range("2017-05-03", "2018-10-06")
idx = pd.DatetimeIndex(dt)

df=df.reindex(idx)
df
# Out:
#             temp  windspeed event
# 2017-05-03   NaN        NaN   NaN
# 2017-05-04   NaN        NaN   NaN
# 2017-05-05   NaN        NaN   NaN
# 2017-05-06   NaN        NaN   NaN
# 2017-05-07   NaN        NaN   NaN
# ...          ...        ...   ...
# 2018-10-02   NaN        NaN   NaN
# 2018-10-03   NaN        NaN   NaN
# 2018-10-04   NaN        NaN   NaN
# 2018-10-05   NaN        NaN   NaN
# 2018-10-06   NaN        NaN   NaN
#
# [522 rows x 3 columns]

# %%
import numpy as np
import pandas as pd
df = pd.read_csv(r"C:\Users\chand\OneDrive\Documents\WEATHER_FILE.csv")
df
# Out:
#           day     temp  windspeed   event
# 0  03-05-2017     32.2        6.0    RAIN
# 1  02-06-2013 -99999.0        6.5   SUNNY
# 2  06-12-2018     70.0   -88888.0  -12121

# %%
import numpy as np
new_df=df.replace([-99999,-88888,-12121],np.NaN)
new_df
# Out:
#           day  temp  windspeed   event
# 0  03-05-2017  32.2        6.0    RAIN
# 1  02-06-2013   NaN        6.5   SUNNY
# 2  06-12-2018  70.0        NaN  -12121

# %%
new_df=df.replace({"temp":-99999,
                   "windspeed":-88888,
                   "event":0},np.NaN)
new_df
# Out:
#           day  temp  windspeed   event
# 0  03-05-2017  32.2        6.0    RAIN
# 1  02-06-2013   NaN        6.5   SUNNY
# 2  06-12-2018  70.0        NaN  -12121

# %%
new_df=df.replace('[a-zA-Z]','',regex=True)
new_df
# Out:
#           day     temp  windspeed   event
# 0  03-05-2017     32.2        6.0
# 1  02-06-2013 -99999.0        6.5
# 2  06-12-2018     70.0   -88888.0  -12121

# %%
df=df_employee=pd.DataFrame({"name":["yogi","jogi","mogi","dogi"],
                          "age":[20,10,50,31],
                          "salary":[2300,6500,3210,5644]})
df
# Out:
#    name  age  salary
# 0  yogi   20    2300
# 1  jogi   10    6500
# 2  mogi   50    3210
# 3  dogi   31    5644

# %%
df=df.replace(['yogi','jogi','mogi','dogi'],[6,3,7,9])
df
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_14580\703985215.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df=df.replace(['yogi','jogi','mogi','dogi'],[6,3,7,9])
#    name  age  salary
# 0     6   20    2300
# 1     3   10    6500
# 2     7   50    3210
# 3     9   31    5644

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\chand\OneDrive\Documents\WEATHER_FILE.csv")
df
# Out:
#            day   temp  windspeed  event    city
# 0   03-05-2017   32.2        6.0   RAIN  madrid
# 1   02-06-2013  330.0        6.5  SUNNY  mumbai
# 2   06-12-2018   70.0        6.3   RAIN  ambala
# 3   03-05-2017   56.0        5.0  SUNNY  mumbai
# 4   02-06-2013   52.0        4.0    fog  mumbai
# 5   06-12-2018   12.0        6.0  SUNNY  madrid
# 6   02-06-2013    6.0       99.0    fog  madrid
# 7   06-12-2018   35.0        8.0   RAIN  madrid
# 8   03-05-2017   31.0        9.0  SUNNY  ambala
# 9   02-06-2013   16.0        5.0   RAIN  ambala
# 10  06-12-2018  119.0        1.0  SUNNY  ambala

# %%
g=df.groupby("city")
g

# %%
for city ,city_df in g:
    print(city)
    print(city_df)
# Out:
# ambala
#            day   temp  windspeed  event    city
# 2   06-12-2018   70.0        6.3   RAIN  ambala
# 8   03-05-2017   31.0        9.0  SUNNY  ambala
# 9   02-06-2013   16.0        5.0   RAIN  ambala
# 10  06-12-2018  119.0        1.0  SUNNY  ambala
# madrid
#           day  temp  windspeed  event    city
# 0  03-05-2017  32.2        6.0   RAIN  madrid
# 5  06-12-2018  12.0        6.0  SUNNY  madrid
# 6  02-06-2013   6.0       99.0    fog  madrid
# 7  06-12-2018  35.0        8.0   RAIN  madrid
# mumbai
#           day   temp  windspeed  event    city
# 1  02-06-2013  330.0        6.5  SUNNY  mumbai
# 3  03-05-2017   56.0        5.0  SUNNY  mumbai
# 4  02-06-2013   52.0        4.0    fog  mumbai

# %%
g.get_group("madrid")
# Out:
#           day  temp  windspeed  event    city
# 0  03-05-2017  32.2        6.0   RAIN  madrid
# 5  06-12-2018  12.0        6.0  SUNNY  madrid
# 6  02-06-2013   6.0       99.0    fog  madrid
# 7  06-12-2018  35.0        8.0   RAIN  madrid

# %%
g.max()
# Out:
#                day   temp  windspeed  event
# city
# ambala  06-12-2018  119.0        9.0  SUNNY
# madrid  06-12-2018   35.0       99.0    fog
# mumbai  03-05-2017  330.0        6.5    fog

# %%
g.mean(city)
# Out:
#          temp  windspeed
# city
# ambala   59.0   5.325000
# madrid   21.3  29.750000
# mumbai  146.0   5.166667

# %%
g.describe()
# Out:
#         temp                                                      windspeed  \
#        count   mean         std   min    25%   50%     75%    max     count
# city
# ambala   4.0   59.0   46.021734  16.0  27.25  50.5   82.25  119.0       4.0
# madrid   4.0   21.3   14.457755   6.0  10.50  22.1   32.90   35.0       4.0
# mumbai   3.0  146.0  159.361225  52.0  54.00  56.0  193.00  330.0       3.0
#
#
#              mean        std  min  25%   50%     75%   max
# city
# ambala   5.325000   3.330040  1.0  4.0  5.65   6.975   9.0
# madrid  29.750000  46.176293  6.0  6.0  7.00  30.750  99.0
# mumbai   5.166667   1.258306  4.0  4.5  5.00   5.750   6.5

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# ambala    Axes(0.125,0.11;0.775x0.77)
# madrid    Axes(0.125,0.11;0.775x0.77)
# mumbai    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
import pandas as pd
india_weather=pd.DataFrame({'city':['mumbai','delhi','gurgaon']
                            ,'temp':[32,39,31]
                            ,'humidity':[90,60,50]})
india_weather
# Out:
#       city  temp  humidity
# 0   mumbai    32        90
# 1    delhi    39        60
# 2  gurgaon    31        50

# %%
usa_weather=pd.DataFrame({'city':['manhaten','los angelas','las vegas']
                            ,'temp':[21,20,19]
                            ,'humidity':[51,42,39]})
usa_weather
# Out:
#           city  temp  humidity
# 0     manhaten    21        51
# 1  los angelas    20        42
# 2    las vegas    19        39

# %%
df=pd.concat([india_weather,usa_weather],ignore_index=True)
df
# Out:
#           city  temp  humidity
# 0       mumbai    32        90
# 1        delhi    39        60
# 2      gurgaon    31        50
# 3     manhaten    21        51
# 4  los angelas    20        42
# 5    las vegas    19        39

# %%
df=pd.concat([india_weather,usa_weather],keys=['india','usa'])
df
# Out:
#                 city  temp  humidity
# india 0       mumbai    32        90
#       1        delhi    39        60
#       2      gurgaon    31        50
# usa   0     manhaten    21        51
#       1  los angelas    20        42
#       2    las vegas    19        39

# %%
import pandas as pd
temprature=pd.DataFrame({'city':['mumbai','delhi','gurgaon']
                            ,'temp':[32,39,31]},index=[0,1,2])
temprature
# Out:
#       city  temp
# 0   mumbai    32
# 1    delhi    39
# 2  gurgaon    31

# %%
windspeed=pd.DataFrame({'city':['mumbai','delhi','gurgaon']
                            ,'windspeed':[364,349,311]},index=[0,1,2])
windspeed
# Out:
#       city  windspeed
# 0   mumbai        364
# 1    delhi        349
# 2  gurgaon        311

# %%
df=pd.concat([temprature,windspeed],axis=1)
df
# Out:
#       city  temp     city  windspeed
# 0   mumbai    32   mumbai        364
# 1    delhi    39    delhi        349
# 2  gurgaon    31  gurgaon        311

# %%
import pandas as pd
df3=pd.merge(df1,df2,on="name",how='outer')
df3
# Out:
#    name   age  salary    price groth
# 0  audi   NaN     NaN  50000.0   36%
# 1  dogi  31.0  5644.0      NaN   NaN
# 2   jio   NaN     NaN  20000.0   25%
# 3  jogi  10.0  6500.0      NaN   NaN
# 4  mogi  50.0  3210.0      NaN   NaN
# 5  tata   NaN     NaN  10000.0   52%
# 6  yogi  20.0  2300.0      NaN   NaN

# %%
df3=pd.merge(df1,df2,on="name",how='left')
df3
# Out:
#    name  age  salary  price groth
# 0  yogi   20    2300    NaN   NaN
# 1  jogi   10    6500    NaN   NaN
# 2  mogi   50    3210    NaN   NaN
# 3  dogi   31    5644    NaN   NaN

# %%
df3=pd.merge(df1,df2,on="name",how='right')
df3
# Out:
#    name  age  salary  price groth
# 0   jio  NaN     NaN  20000   25%
# 1  tata  NaN     NaN  10000   52%
# 2  audi  NaN     NaN  50000   36%

# %%
df3=pd.merge(df1,df2,on="name",suffixes=('left','right'))
df3
# Out:
# Empty DataFrame
# Columns: [name, age, salary, price, groth]
# Index: []

# %%
df = df.reset_index(drop=True)
df = df.drop_duplicates()
df.pivot(index="day ", columns="city")

# %%
df.pivot_table(index="city",columns="day",aggfunc="sum",margins=True)

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\chand\OneDrive\Documents\WEATHER_FILE.csv")
df
# Out:
#            day   temp  windspeed  event    city
# 0   03-05-2017   32.2        6.0   RAIN  madrid
# 1   02-06-2013  330.0        6.5  SUNNY  mumbai
# 2   06-12-2018   70.0        6.3   RAIN  ambala
# 3   03-05-2017   56.0        5.0  SUNNY  mumbai
# 4   02-06-2013   52.0        4.0    fog  mumbai
# 5   06-12-2018   12.0        6.0  SUNNY  madrid
# 6   02-06-2013    6.0       99.0    fog  madrid
# 7   06-12-2018   35.0        8.0   RAIN  madrid
# 8   03-05-2017   31.0        9.0  SUNNY  ambala
# 9   02-06-2013   16.0        5.0   RAIN  ambala
# 10  06-12-2018  119.0        1.0  SUNNY  ambala

# %% [markdown]
# #time series anlysis

# %%
import pandas as pd
df1=pd.melt(df,id_vars=["day"])
df1[df1["variable"]=="temp"]
# Out:
#            day variable  value
# 0   03-05-2017     temp   32.2
# 1   02-06-2013     temp  330.0
# 2   06-12-2018     temp   70.0
# 3   03-05-2017     temp   56.0
# 4   02-06-2013     temp   52.0
# 5   06-12-2018     temp   12.0
# 6   02-06-2013     temp    6.0
# 7   06-12-2018     temp   35.0
# 8   03-05-2017     temp   31.0
# 9   02-06-2013     temp   16.0
# 10  06-12-2018     temp  119.0

# %%
df_stacked=df.stack(level=0)
df_stacked
# Out:
# 0   day          03-05-2017
#     temp               32.2
#     windspeed           6.0
#     event              RAIN
#     city             madrid
# 1   day          02-06-2013
#     temp              330.0
#     windspeed           6.5
#     event             SUNNY
#     city             mumbai
# 2   day          06-12-2018
#     temp               70.0
#     windspeed           6.3
#     event              RAIN
#     city             ambala
# 3   day          03-05-2017
#     temp               56.0
#     windspeed           5.0
#     event             SUNNY
#     city             mumbai
# 4   day          02-06-2013
#     temp               52.0
#     windspeed           4.0
#     event               fog
#     city             mumbai
# 5   day          06-12-2018
#     temp               12.0
#     windspeed           6.0
#     event             SUNNY
#     city             madrid
# 6   day          02-06-2013
#     temp                6.0
#     windspeed          99.0
# ...

# %%
df_stacked.unstack()
# Out:
#            day   temp windspeed  event    city
# 0   03-05-2017   32.2       6.0   RAIN  madrid
# 1   02-06-2013  330.0       6.5  SUNNY  mumbai
# 2   06-12-2018   70.0       6.3   RAIN  ambala
# 3   03-05-2017   56.0       5.0  SUNNY  mumbai
# 4   02-06-2013   52.0       4.0    fog  mumbai
# 5   06-12-2018   12.0       6.0  SUNNY  madrid
# 6   02-06-2013    6.0      99.0    fog  madrid
# 7   06-12-2018   35.0       8.0   RAIN  madrid
# 8   03-05-2017   31.0       9.0  SUNNY  ambala
# 9   02-06-2013   16.0       5.0   RAIN  ambala
# 10  06-12-2018  119.0       1.0  SUNNY  ambala

# %%
pd.crosstab([df.temp,df.windspeed],df.event,margins=True)
# Out:
# event            RAIN  SUNNY  fog  All
# temp  windspeed
# 6.0   99.0          0      0    1    1
# 12.0  6.0           0      1    0    1
# 16.0  5.0           1      0    0    1
# 31.0  9.0           0      1    0    1
# 32.2  6.0           1      0    0    1
# 35.0  8.0           1      0    0    1
# 52.0  4.0           0      0    1    1
# 56.0  5.0           0      1    0    1
# 70.0  6.3           1      0    0    1
# 119.0 1.0           0      1    0    1
# 330.0 6.5           0      1    0    1
# All                 4      5    2   11

# %%
import numpy as np
pd.crosstab(df.city,df.windspeed,values=df.temp,aggfunc=np.average)
# Out:
# windspeed   1.0   4.0   5.0   6.0   6.3    6.5   8.0   9.0   99.0
# city
# ambala     119.0   NaN  16.0   NaN  70.0    NaN   NaN  31.0   NaN
# madrid       NaN   NaN   NaN  22.1   NaN    NaN  35.0   NaN   6.0
# mumbai       NaN  52.0  56.0   NaN   NaN  330.0   NaN   NaN   NaN

# %%
pip install pymysql

# %%
import pandas as pd
import sqlalchemy

# %%
engine = sqlalchemy.create_engine("mysql+pymysql://root:@localhost:3306/application")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 engine = sqlalchemy.create_engine("mysql+pymysql://root:@localhost:3306/application")
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py:599, in create_engine(url, **kwargs)
#     597         if k in kwargs:
#     598             dbapi_args[k] = pop_kwarg(k)
# ...
